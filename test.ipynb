# %%
import pandas as pd

data = pd.read_csv("birds.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Taxon_rank         Order    Family      Family_English_name  \
# 0           0    species  Anseriformes  Anatidae  Ducks, Swans, and Geese
# 1           1    species  Anseriformes  Anatidae  Ducks, Swans, and Geese
# 2           2    species  Anseriformes  Anatidae  Ducks, Swans, and Geese
# 3           3    species  Anseriformes  Anatidae  Ducks, Swans, and Geese
# 4           4    species  Anseriformes  Anatidae  Ducks, Swans, and Geese
#
#        Scientific_name English_name_AviList            German_name  \
# 0  Oxyura leucocephala    White-headed Duck     Weißkopf-Ruderente
# 1   Oxyura jamaicensis           Ruddy Duck  Schwarzkopf-Ruderente
# 2          Cygnus olor            Mute Swan           Höckerschwan
# 3        Cygnus cygnus         Whooper Swan             Singschwan
# 4      Branta bernicla          Brant Goose             Ringelgans
#
#                                      Status Rl-status
# 0                       Ausnahmeerscheinung
# ...

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'Taxon_rank', 'Order', 'Family', 'Family_English_name',
#        'Scientific_name', 'English_name_AviList', 'German_name', 'Status',
#        'Rl-status'],
#       dtype='str')
